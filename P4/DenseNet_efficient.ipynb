# %%
# !pip install fire
# Out:
# ...
#      |████████████████████████████████| 87 kB 3.5 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=cc2e2893e208f37fff16030cd1c8f246d9da055c8d8136371869678460f51e56
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2 python demo.py --efficient True --data <path_to_folder_with_cifar10> --save <path_to_save_dir>
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: `CUDA_VISIBLE_DEVICES=0,1,2 python demo.py --efficient True --data <path_to_folder_with_cifar10> --save <path_to_save_dir>'

# %%
# !git init
# !git clone https://github.com/gpleiss/efficient_densenet_pytorch
# Out:
# Reinitialized existing Git repository in /content/.git/
# Cloning into 'efficient_densenet_pytorch'...
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 409 (delta 0), reused 0 (delta 0), pack-reused 405
# Receiving objects: 100% (409/409), 1.12 MiB | 5.79 MiB/s, done.
# Resolving deltas: 100% (232/232), done.

# %%
# !python efficient_densenet_pytorch/demo.py --efficient True --data efficient_densenet_pytorch --save efficient_densenet_pytorch --n_epochs 10 --depth 40 --growth_rate 12
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [4/10]	Iter: [646/704]	Time 0.057 (0.058)	Loss 0.7042 (0.7118)	Error 0.2500 (0.2480)
# Epoch: [4/10]	Iter: [647/704]	Time 0.057 (0.058)	Loss 0.4639 (0.7115)	Error 0.1562 (0.2478)
# Epoch: [4/10]	Iter: [648/704]	Time 0.057 (0.058)	Loss 0.3661 (0.7109)	Error 0.0938 (0.2476)
# Epoch: [4/10]	Iter: [649/704]	Time 0.057 (0.058)	Loss 0.6676 (0.7109)	Error 0.2031 (0.2475)
# Epoch: [4/10]	Iter: [650/704]	Time 0.063 (0.058)	Loss 0.6445 (0.7108)	Error 0.2188 (0.2475)
# Epoch: [4/10]	Iter: [651/704]	Time 0.057 (0.058)	Loss 1.0984 (0.7114)	Error 0.3594 (0.2476)
# Epoch: [4/10]	Iter: [652/704]	Time 0.056 (0.058)	Loss 0.8055 (0.7115)	Error 0.2656 (0.2477)
# Epoch: [4/10]	Iter: [653/704]	Time 0.057 (0.058)	Loss 0.7592 (0.7116)	Error 0.2969 (0.2478)
# Epoch: [4/10]	Iter: [654/704]	Time 0.056 (0.058)	Loss 0.5996 (0.7114)	Error 0.1875 (0.2477)
# Epoch: [4/10]	Iter: [655/704]	Time 0.058 (0.058)	Loss 0.8461 (0.7116)	Error 0.2344 (0.2476)
# ...

# %%
# !python efficient_densenet_pytorch/demo.py --efficient True --data efficient_densenet_pytorch --save efficient_densenet_pytorch --n_epochs 10 --depth 100 --growth_rate 12
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [4/10]	Iter: [645/704]	Time 0.241 (0.243)	Loss 0.2939 (0.6062)	Error 0.1094 (0.2077)
# Epoch: [4/10]	Iter: [646/704]	Time 0.240 (0.243)	Loss 0.4783 (0.6060)	Error 0.1875 (0.2076)
# Epoch: [4/10]	Iter: [647/704]	Time 0.241 (0.243)	Loss 0.5027 (0.6059)	Error 0.1875 (0.2076)
# Epoch: [4/10]	Iter: [648/704]	Time 0.241 (0.243)	Loss 0.4317 (0.6056)	Error 0.1562 (0.2075)
# Epoch: [4/10]	Iter: [649/704]	Time 0.240 (0.243)	Loss 0.6842 (0.6057)	Error 0.2969 (0.2077)
# Epoch: [4/10]	Iter: [650/704]	Time 0.241 (0.243)	Loss 0.4108 (0.6054)	Error 0.1250 (0.2075)
# Epoch: [4/10]	Iter: [651/704]	Time 0.241 (0.243)	Loss 0.6818 (0.6056)	Error 0.2812 (0.2076)
# Epoch: [4/10]	Iter: [652/704]	Time 0.240 (0.243)	Loss 0.6634 (0.6056)	Error 0.2812 (0.2078)
# Epoch: [4/10]	Iter: [653/704]	Time 0.239 (0.243)	Loss 0.5576 (0.6056)	Error 0.1875 (0.2077)
# Epoch: [4/10]	Iter: [654/704]	Time 0.241 (0.243)	Loss 0.6108 (0.6056)	Error 0.1875 (0.2077)
# ...

# %%
# !python efficient_densenet_pytorch/demo.py --efficient True --data efficient_densenet_pytorch --save efficient_densenet_pytorch --n_epochs 10 --depth 100 --growth_rate 24
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [4/10]	Iter: [648/704]	Time 0.480 (0.481)	Loss 0.3795 (0.5597)	Error 0.1250 (0.1921)
# Epoch: [4/10]	Iter: [649/704]	Time 0.480 (0.481)	Loss 0.4896 (0.5596)	Error 0.1406 (0.1920)
# Epoch: [4/10]	Iter: [650/704]	Time 0.480 (0.481)	Loss 0.4501 (0.5594)	Error 0.1406 (0.1919)
# Epoch: [4/10]	Iter: [651/704]	Time 0.484 (0.481)	Loss 0.5487 (0.5594)	Error 0.1562 (0.1919)
# Epoch: [4/10]	Iter: [652/704]	Time 0.484 (0.481)	Loss 0.5671 (0.5594)	Error 0.1875 (0.1919)
# Epoch: [4/10]	Iter: [653/704]	Time 0.479 (0.481)	Loss 0.3150 (0.5591)	Error 0.0938 (0.1917)
# Epoch: [4/10]	Iter: [654/704]	Time 0.483 (0.481)	Loss 0.3989 (0.5588)	Error 0.1406 (0.1916)
# Epoch: [4/10]	Iter: [655/704]	Time 0.483 (0.481)	Loss 0.3202 (0.5584)	Error 0.1094 (0.1915)
# Epoch: [4/10]	Iter: [656/704]	Time 0.483 (0.481)	Loss 0.3148 (0.5581)	Error 0.1094 (0.1914)
# Epoch: [4/10]	Iter: [657/704]	Time 0.480 (0.481)	Loss 0.3382 (0.5577)	Error 0.1250 (0.1913)
# ...
